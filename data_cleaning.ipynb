# %%
import pandas as pd
import numpy as np
import requests
import json
from config import key_dict

# %%
data_2018 = pd.read_csv('Resources/aqidaily2018.csv')
data_2019 = pd.read_csv('Resources/aqidaily2019.csv')
data_2020 = pd.read_csv('Resources/aqidaily2020.csv')
data_2021 = pd.read_csv('Resources/aqidaily2021.csv')

# %%
aqi_data = data_2018.append(data_2019, ignore_index = True)
aqi_data = aqi_data.append(data_2020, ignore_index = True)
aqi_data = aqi_data.append(data_2021, ignore_index = True)
aqi_data
# Out:
#             Date  Overall AQI Value Main Pollutant Site Name (of Overall AQI)  \
# 0     01/01/2018                139          PM2.5                    Donovan
# 1     01/02/2018                 94          PM2.5                    Donovan
# 2     01/03/2018                 94          PM2.5                Chula Vista
# 3     01/04/2018                 76          PM2.5                    Donovan
# 4     01/05/2018                 78          PM2.5                    Donovan
# ...          ...                ...            ...                        ...
# 1171  03/20/2021                 42          Ozone                Chula Vista
# 1172  03/21/2021                 48          Ozone                     Alpine
# 1173  03/22/2021                 50          Ozone                     Alpine
# 1174  03/23/2021                 44          Ozone                     Alpine
# 1175  03/24/2021                 52          PM2.5                    Donovan
#
# ...

# %%
aqi_data.to_csv('Resources/aqi_data.csv',index=False)
